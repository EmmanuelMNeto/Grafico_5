# %% [markdown]
# ## importando o pandas

# %%
#!pip install pandas
#!pip install matplotlib

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df_sp = pd.read_csv('Frota de veículos - São Paulo.csv', sep=';')

display(df_sp.head(1))
# Out:
#   Nível Indicador        2006        2007        2008        2009        2010  \
# 0     1   Veículo  15098096.0  16464703.0  17852829.0  19139118.0  20537980.0
#
#          2011        2012        2013  ...        2015        2016  \
# 0  21968359.0  23286890.0  24560202.0  ...  26605042.0  27332101.0
#
#          2017        2018        2019        2020        2021        2022  \
# 0  28138698.0  29057749.0  30058975.0  30778960.0  31455473.0  32293191.0
#
#          2023   Unidade
# 0  33264096.0  veículos
#
# [1 rows x 21 columns]

# %% [markdown]
# ## Filtrando o dataframe

# %%
# df_sp_formatado = df_sp.drop(columns=['Nível','2006', '2007', '2008','2009','2010','2011','2012', '2013', '2014', '2015','2016','2017','2018','2019', '2020', '2021', '2022','Unidade'])

# display(df_sp_formatado.head(50))

df_sp_formatado = df_sp [['2023', 'Indicador']] 

df_sp_formatado = df_sp_formatado[
                                 (df_sp_formatado['Indicador'].str.contains('Automóvel'))
                                |(df_sp_formatado['Indicador'].str.contains('Motocicleta'))
                                |(df_sp_formatado['Indicador'].str.contains('Ônibus'))
                                |(df_sp_formatado['Indicador'].str.contains('Caminhão'))
                                |(df_sp_formatado['Indicador'].str.contains('Caminhonete'))
                                ]
df_sp_formatado
# Out:
#           2023        Indicador
# 2   20032335.0        Automóvel
# 4     723325.0         Caminhão
# 5     219377.0  Caminhão trator
# 6    2332606.0      Caminhonete
# 11   5538201.0      Motocicleta
# 13    173461.0           Ônibus

# %%
# Crie uma figura com 15 polegadas de largura e 10 polegadas de altura
plt.figure(figsize=(15, 10))


plt.plot(df_sp_formatado['Indicador'], df_sp_formatado['2023'], label='indicador')

# Adicione uma legenda ao criar gráfico no Python
plt.legend()

# Adicione um título ao gráfico
plt.title("Quantidades de veiculos em São Paulo")

# Comando para exibir e criar gráfico no Python
plt.show()

# %%
plt.style.use('_mpl-gallery')

fig, ax = plt.subplots(figsize=(15, 10))
# make data:
x = df_sp_formatado ['Indicador']
y = df_sp_formatado ['2023']

cores = ['#66b3ff', '#66b3ff', '#66b3ff', '#66b3ff', '#66b3ff']


ax.bar(x, y, width=1, edgecolor="white", linewidth=1.0, color=cores)
ax.set_facecolor('grey')


#ax.set(xlim=(0, 8), xticks=np.arange(1, 8),
#       ylim=(0, 8), yticks=np.arange(1, 8))

plt.show()

# %%
df_dados = pd.read_excel('dados.xlsx',)

display(df_dados)
# Out:
#                                            descricao  vl_fim_Abril  \
# 0             Frota de ônibus elétricos em São Paulo        149.00
# 1                  Meta de ônibus para o fim de 2024       2600.00
# 2                       Percentual cumprido da meta           5.73
# 3                 Frota anterior de ônibus elétricos           NaN
# 4           Novos ônibus elétricos até junho de 2024         71.00
# 5              Número de trólebus operando na cidade           NaN
# 6      Meta de troca da frota de ônibus a diesel (%)           NaN
# 7             Recursos para renovação da frota (PAC)           NaN
# 8  Quantidade de ônibus a serem contemplados pelo...           NaN
#
#     vl_ini_Maio   vl_fim_Maio
# 0  1.710000e+02  1.790000e+02
# 1  2.600000e+03  2.600000e+03
# 2  6.570000e+00  6.880000e+00
# 3  1.490000e+02  1.710000e+02
# 4  4.900000e+01  4.100000e+01
# 5  2.010000e+02  2.010000e+02
# 6  2.000000e+01  2.000000e+01
# 7  1.000000e+09  1.000000e+09
# ...

# %%
# Criando um DataFrame a partir dos dados da tabela
# dados = {
#     'Descrição': ['Frota de ônibus elétricos em São Paulo', 'Meta de ônibus para o fim de 2024', 'Percentual cumprido da meta', 'Frota anterior de ônibus elétricos', 'Novos ônibus elétricos até junho de 2024', 'Número de trólebus operando na cidade', 'Meta de troca da frota de ônibus a diesel', 'Recursos para renovação da frota (PAC)', 'Quantidade de ônibus a serem contemplados pelo P...'],
#     'Valor': [171, 2600, 6.57, 149, 49, 201, 20, 10000000, 5000]
# }
# df = pd.DataFrame(dados)

# Gráfico de Barras: Comparação entre frota atual e meta
plt.bar(['Frota Atual', 'Meta 2024'], [df_dados['vl_ini_Maio'][0], df_dados['vl_ini_Maio'][1]])
plt.title('Frota de Ônibus Elétricos em São Paulo')
plt.ylabel('Número de Ônibus')
plt.show()

# Gráfico de Pizza: Percentual da meta cumprida
plt.pie([df_dados['vl_ini_Maio'][2], 100-df_dados['vl_ini_Maio'][2]], labels=['Meta Cumprida', 'Meta Restante'], autopct='%1.1f%%')
plt.title('Percentual da Meta Cumprida')
plt.show()

# %%
# Dados (exemplo)
dados = {'Ano': [2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022],
         'Número de Ônibus': [10, 25, 40, 60, 80, 100, 120, 171]}
df = pd.DataFrame(dados)

# Gráfico de Linha
plt.plot(df['Ano'], df['Número de Ônibus'])
plt.xlabel('Ano')
plt.ylabel('Número de Ônibus Elétricos')
plt.title('Evolução da Frota de Ônibus Elétricos em São Paulo')
plt.show()

# %%
vl_abril = df_dados['vl_fim_Abril'][0]
vl_ini_Maio = df_dados['vl_ini_Maio'][0]
vl_fim_Maio= df_dados['vl_fim_Maio'][0]

lista_variavel = [vl_abril, vl_ini_Maio, vl_fim_Maio]

# %%
# Gráfico de Linha
plt.plot(df_dados['vl_fim_Abril', 'vl_ini_Maio', 'vl_fim_Maio'], lista_variavel)
plt.xlabel('Mês')
plt.ylabel('Número de Ônibus Elétricos')
plt.title('Evolução da Frota de Ônibus Elétricos em São Paulo')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'vlista_variavel'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...
